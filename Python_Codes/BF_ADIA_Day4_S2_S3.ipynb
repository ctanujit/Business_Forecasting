# %% [markdown]
# # 👨‍💻 Coding a neural net
# Alright, finally we are here. Don't wanna talk about much let's keep coding straightly, have to explore a lot of stuff here. We will be trying the NN on the our old school *airline passengers* dataset.
#
# Let's go!

# %%
# usual imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams["figure.figsize"] = (8, 6)

# deep imports
import tensorflow as tf

# the evaluation
from sklearn.metrics import mean_absolute_percentage_error, r2_score
from tensorflow.keras.layers import Dense, Input  # to create layer
from tensorflow.keras.models import Model  # whole model

# %% [markdown]
# Damn, this time apart from metrics, there is no `sklearn` import at all!

# %%
# we can put the seeds for tensorflow this way
tf.random.set_seed(42)

# %%
passengers = pd.read_csv(
    "/content/airline_passengers.csv", parse_dates=True, index_col=0
)

# %%
passengers.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# A bit of plotting as a refresher.

# %%
passengers.plot()
plt.title("Passengers data");

# %% [markdown]
# Done. Let's start creating the models.
#
# The outline of this notebook:
# 1. Create a **one-step** model
# 2. Create a **multi-step** / incremental model
# 3. Create a **multi-output** / MTR model
#
# After that, we will *try* other stuff like:
# - Training all of those (from steps 1, 2, 3) models *without* differencing.

# %% [markdown]
# #####

# %% [markdown]
# ## Differenceing

# %%
passengers["diffPassengers"] = passengers["Passengers"].diff()

# %%
passengers.head()
# Out:
#             Passengers  diffPassengers
# Month
# 1949-01-01         112             NaN
# 1949-02-01         118             6.0
# 1949-03-01         132            14.0
# 1949-04-01         129            -3.0
# 1949-05-01         121            -8.0

# %% [markdown]
# ## `1.` One step model

# %%
lag = 12
train_idx = passengers.iloc[:-lag].index
test_idx = passengers.iloc[-lag:].index

# %%
np_data = passengers.loc[:, "diffPassengers"].dropna().values
X = []
Y = []

for i in range(0, np_data.shape[0] - lag):
    x = np_data[i : i + lag]
    y = np_data[i + lag]
    X.append(x)
    Y.append(y)

X = np.array(X)
Y = np.array(Y)

# %%
Xtr, Xte = X[:-lag], X[-lag:]
ytr, yte = Y[:-lag], Y[-lag:]

# %% [markdown]
# ## Model creation

# %% [markdown]
# #### ➡ Input layer

# %%
# set the input layer
input_layer = Input(shape=(Xtr.shape[1],))

# %% [markdown]
# There, we have initialized the input with `12` nodes. Which are the number of columns. They are coming based on the `lag` variable that we have set there.

# %%
input_layer
# Out:
# <KerasTensor: shape=(None, 12) dtype=float32 (created by layer 'input_1')>

# %% [markdown]
# Now, we will go ahead and add the first *hidden layer* in the NN.

# %% [markdown]
# #### ➡ Hidden layer

# %%
# first hidden layer
h1 = Dense(units=32, activation="relu")

# %% [markdown]
# There, we have just made `1st` **hidden** layer with 32 nodes inside with the activation "relu". If we would have passed nothing in the `activation` parameter, then it would **not** apply any activation at all!
#
# The available activation functions are...

# %%
from tensorflow.keras import activations

activations.relu
# Out:
# <function keras.src.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)>

# %% [markdown]
# #### ➡ Hidden layer connection with previous layer

# %%
# we can use the "brackets" with the object to connect with the layer
h1(input_layer)
# Out:
# <KerasTensor: shape=(None, 32) dtype=float32 (created by layer 'dense')>

# %% [markdown]
# Don't be surprised, it is simply done with the `__call__` magic method in the `Dense` class! A python thing.
#
# So, that can be re-written as...

# %%
# connection in single step
h1 = Dense(32, activation="relu")(input_layer)

# %% [markdown]
# Simple!

# %% [markdown]
# #### ➡ Hidden layer (x2)

# %%
h2 = Dense(16, activation="relu")(h1)

# %% [markdown]
# So, till now — we have created a NN with:
# - 12 input nodes
# - 32 1st layer nodes
# - 16 2nd layer nodes
#
# And now we will be making the final, output layer.

# %% [markdown]
# #### ➡ Output layer

# %%
output_layer = Dense(1, activation=None)(h2)

# %% [markdown]
# That simple! Just **take care** of the **conections**. That what you are connecting with what.

# %% [markdown]
# #### ➡ Everything in a single pack = Model

# %%
model = Model(input_layer, output_layer)

# %% [markdown]
# Which from their doc:
#
#     `Model` groups layers into an object with training and inference features.
#
#     Args:
#         inputs: The input(s) of the model: a `keras.Input` object or list of
#             `keras.Input` objects.
#         outputs: The output(s) of the model. See Functional API example below.
#         name: String, the name of the model.

# %%
# everything in a single cell
input_layer = Input(shape=(Xtr.shape[1],))
h1 = Dense(32, activation="relu")(input_layer)
h2 = Dense(16, activation="relu")(h1)
output_layer = Dense(1, activation=None)(h2)
model = Model(input_layer, output_layer)

# %% [markdown]
# Our neural net is ready bois!

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 12)]              0
#
#  dense_4 (Dense)             (None, 32)                416
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 961 (3.75 KB)
# Trainable params: 961 (3.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### ➡ Compile the model

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mse", "mape"])

# %% [markdown]
# This will let the model know which way it should get trained. There are multiple methods. I know, it is abstract, but in the course it is unnecessary to go in those details. I am pretty sure, when I will be learning deep learning **"deeply"**, I will get to know them as well.
#
# But, for now — keep that in mind that there are multiple optimizers available for our model to get trained.

# %%
from tensorflow.keras import optimizers
optimizers.Adam
# Out:
# keras.src.optimizers.adam.Adam

# %%
from tensorflow.keras import losses
losses.mse
# Out:
# <function keras.src.losses.mean_squared_error(y_true, y_pred)>

# %% [markdown]
# Yeah, there are a lot of them.

# %%
from tensorflow.keras import metrics
metrics.Accuracy
# Out:
# keras.src.metrics.accuracy_metrics.Accuracy

# %% [markdown]
# Ah, writing a lot lately... but still worth exploring that these are the options available!

# %%
result = model.fit(Xtr, ytr,
         epochs=100,
         validation_data=(Xte, yte), verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 91ms/step - loss: 1080.7047 - mse: 1080.7047 - mape: 197267280.0000 - val_loss: 1939.0890 - val_mse: 1939.0890 - val_mape: 88.2300
# Epoch 2/100
# 4/4 [==============================] - 0s 20ms/step - loss: 963.1905 - mse: 963.1905 - mape: 168243680.0000 - val_loss: 1726.2872 - val_mse: 1726.2872 - val_mape: 81.3902
# Epoch 3/100
# 4/4 [==============================] - 0s 16ms/step - loss: 847.7568 - mse: 847.7568 - mape: 158008752.0000 - val_loss: 1546.8026 - val_mse: 1546.8026 - val_mape: 75.2826
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 754.1439 - mse: 754.1439 - mape: 141846080.0000 - val_loss: 1387.9425 - val_mse: 1387.9425 - val_mape: 70.8308
# Epoch 5/100
# 4/4 [==============================] - 0s 15ms/step - loss: 672.9983 - mse: 672.9983 - mape: 131583240.0000 - val_loss: 1240.8062 - val_mse: 1240.8062 - val_mape: 67.5553
# Epoch 6/100
# 4/4 [==============================] - 0s 20ms/step - loss: 591.6179 - mse: 591.6179 - mape: 125771496.0000 - val_loss: 1129.4940 - val_mse: 1129.4940 - val_mape: 64.5181
# Epoch 7/100
# 4/4 [==============================] - 0s 25ms/step - loss: 530.1214 - mse: 530.1214 - mape: 119628792.0000 - val_loss: 1031.1926 - val_mse: 1031.1926 - val_mape: 61.3980
# Epoch 8/100
# 4/4 [==============================] - 0s 15ms/step - loss: 468.2855 - mse: 468.2855 - mape: 112118240.0000 - val_loss: 947.0762 - val_mse: 947.0762 - val_mape: 58.7292
# Epoch 9/100
# 4/4 [==============================] - 0s 22ms/step - loss: 414.7874 - mse: 414.7874 - mape: 108006144.0000 - val_loss: 867.1613 - val_mse: 867.1613 - val_mape: 55.7354
# Epoch 10/100
# 4/4 [==============================] - 0s 15ms/step - loss: 362.4941 - mse: 362.4941 - mape: 105524928.0000 - val_loss: 790.0415 - val_mse: 790.0415 - val_mape: 54.5544
# Epoch 11/100
# 4/4 [==============================] - 0s 20ms/step - loss: 318.6609 - mse: 318.6609 - mape: 102425840.0000 - val_loss: 724.3087 - val_mse: 724.3087 - val_mape: 54.2706
# Epoch 12/100
# 4/4 [==============================] - 0s 15ms/step - loss: 282.3147 - mse: 282.3147 - mape: 97070968.0000 - val_loss: 668.0939 - val_mse: 668.0939 - val_mape: 54.2558
# Epoch 13/100
# 4/4 [==============================] - 0s 20ms/step - loss: 243.6376 - mse: 243.6376 - mape: 96526856.0000 - val_loss: 621.0009 - val_mse: 621.0009 - val_mape: 55.2492
# Epoch 14/100
# 4/4 [==============================] - 0s 20ms/step - loss: 211.6275 - mse: 211.6275 - mape: 90312840.0000 - val_loss: 583.2487 - val_mse: 583.2487 - val_mape: 56.3203
# Epoch 15/100
# 4/4 [==============================] - 0s 21ms/step - loss: 184.4679 - mse: 184.4679 - mape: 87109560.0000 - val_loss: 552.9161 - val_mse: 552.9161 - val_mape: 57.4025
# Epoch 16/100
# 4/4 [==============================] - 0s 15ms/step - loss: 163.0599 - mse: 163.0599 - mape: 84403376.0000 - val_loss: 529.1428 - val_mse: 529.1428 - val_mape: 57.6486
# Epoch 17/100
# 4/4 [==============================] - 0s 21ms/step - loss: 144.6835 - mse: 144.6835 - mape: 78938888.0000 - val_loss: 510.7230 - val_mse: 510.7230 - val_mape: 57.7894
# Epoch 18/100
# 4/4 [==============================] - 0s 14ms/step - loss: 127.8474 - mse: 127.8474 - mape: 75504856.0000 - val_loss: 498.7021 - val_mse: 498.7021 - val_mape: 58.4997
# Epoch 19/100
# 4/4 [==============================] - 0s 14ms/step - loss: 114.7132 - mse: 114.7132 - mape: 71312448.0000 - val_loss: 489.7236 - val_mse: 489.7236 - val_mape: 58.7286
# Epoch 20/100
# 4/4 [==============================] - 0s 21ms/step - loss: 106.8981 - mse: 106.8981 - mape: 65447548.0000 - val_loss: 481.6916 - val_mse: 481.6916 - val_mape: 58.8050
# Epoch 21/100
# 4/4 [==============================] - 0s 14ms/step - loss: 98.4711 - mse: 98.4711 - mape: 58354468.0000 - val_loss: 477.3605 - val_mse: 477.3605 - val_mape: 58.4114
# Epoch 22/100
# 4/4 [==============================] - 0s 20ms/step - loss: 92.2873 - mse: 92.2873 - mape: 55487424.0000 - val_loss: 474.4246 - val_mse: 474.4246 - val_mape: 58.2612
# Epoch 23/100
# 4/4 [==============================] - 0s 15ms/step - loss: 86.2635 - mse: 86.2635 - mape: 47352872.0000 - val_loss: 473.5343 - val_mse: 473.5343 - val_mape: 57.7306
# Epoch 24/100
# 4/4 [==============================] - 0s 15ms/step - loss: 81.9605 - mse: 81.9605 - mape: 41751412.0000 - val_loss: 472.3767 - val_mse: 472.3767 - val_mape: 57.0870
# Epoch 25/100
# 4/4 [==============================] - 0s 20ms/step - loss: 78.9655 - mse: 78.9655 - mape: 37959616.0000 - val_loss: 471.4812 - val_mse: 471.4812 - val_mape: 56.1212
# Epoch 26/100
# 4/4 [==============================] - 0s 20ms/step - loss: 75.3116 - mse: 75.3116 - mape: 33896684.0000 - val_loss: 471.8069 - val_mse: 471.8069 - val_mape: 55.4099
# Epoch 27/100
# 4/4 [==============================] - 0s 20ms/step - loss: 72.5643 - mse: 72.5643 - mape: 27857208.0000 - val_loss: 472.4798 - val_mse: 472.4798 - val_mape: 54.8150
# Epoch 28/100
# 4/4 [==============================] - 0s 20ms/step - loss: 70.3576 - mse: 70.3576 - mape: 23984914.0000 - val_loss: 473.9672 - val_mse: 473.9672 - val_mape: 54.4004
# Epoch 29/100
# 4/4 [==============================] - 0s 20ms/step - loss: 68.4213 - mse: 68.4213 - mape: 21872762.0000 - val_loss: 476.3529 - val_mse: 476.3529 - val_mape: 54.3130
# Epoch 30/100
# 4/4 [==============================] - 0s 14ms/step - loss: 66.7923 - mse: 66.7923 - mape: 19336458.0000 - val_loss: 478.1095 - val_mse: 478.1095 - val_mape: 54.1104
# Epoch 31/100
# 4/4 [==============================] - 0s 23ms/step - loss: 65.2118 - mse: 65.2118 - mape: 19085962.0000 - val_loss: 478.9148 - val_mse: 478.9148 - val_mape: 53.8771
# Epoch 32/100
# 4/4 [==============================] - 0s 15ms/step - loss: 63.8994 - mse: 63.8994 - mape: 19879990.0000 - val_loss: 478.0031 - val_mse: 478.0031 - val_mape: 53.5385
# Epoch 33/100
# 4/4 [==============================] - 0s 14ms/step - loss: 62.6627 - mse: 62.6627 - mape: 20880672.0000 - val_loss: 476.1626 - val_mse: 476.1626 - val_mape: 53.4341
# Epoch 34/100
# 4/4 [==============================] - 0s 20ms/step - loss: 61.7512 - mse: 61.7512 - mape: 21627600.0000 - val_loss: 475.9488 - val_mse: 475.9488 - val_mape: 53.3523
# Epoch 35/100
# 4/4 [==============================] - 0s 20ms/step - loss: 60.6571 - mse: 60.6571 - mape: 21886340.0000 - val_loss: 476.0379 - val_mse: 476.0379 - val_mape: 53.2810
# Epoch 36/100
# 4/4 [==============================] - 0s 21ms/step - loss: 59.8988 - mse: 59.8988 - mape: 23298920.0000 - val_loss: 476.5141 - val_mse: 476.5141 - val_mape: 53.0785
# Epoch 37/100
# 4/4 [==============================] - 0s 15ms/step - loss: 59.0932 - mse: 59.0932 - mape: 24234296.0000 - val_loss: 475.5182 - val_mse: 475.5182 - val_mape: 52.9532
# Epoch 38/100
# 4/4 [==============================] - 0s 23ms/step - loss: 58.4842 - mse: 58.4842 - mape: 24614858.0000 - val_loss: 477.0837 - val_mse: 477.0837 - val_mape: 53.0052
# Epoch 39/100
# 4/4 [==============================] - 0s 14ms/step - loss: 57.9348 - mse: 57.9348 - mape: 24904666.0000 - val_loss: 476.6851 - val_mse: 476.6851 - val_mape: 52.9699
# Epoch 40/100
# 4/4 [==============================] - 0s 15ms/step - loss: 57.0771 - mse: 57.0771 - mape: 25604386.0000 - val_loss: 477.6139 - val_mse: 477.6139 - val_mape: 53.1207
# Epoch 41/100
# 4/4 [==============================] - 0s 15ms/step - loss: 56.4171 - mse: 56.4171 - mape: 25473674.0000 - val_loss: 479.0243 - val_mse: 479.0243 - val_mape: 53.2623
# Epoch 42/100
# 4/4 [==============================] - 0s 16ms/step - loss: 55.8622 - mse: 55.8622 - mape: 25842396.0000 - val_loss: 478.7047 - val_mse: 478.7047 - val_mape: 53.2456
# Epoch 43/100
# 4/4 [==============================] - 0s 17ms/step - loss: 55.3328 - mse: 55.3328 - mape: 24920338.0000 - val_loss: 480.0235 - val_mse: 480.0235 - val_mape: 53.1201
# Epoch 44/100
# 4/4 [==============================] - 0s 14ms/step - loss: 54.7456 - mse: 54.7456 - mape: 24590444.0000 - val_loss: 478.7700 - val_mse: 478.7700 - val_mape: 53.0250
# Epoch 45/100
# 4/4 [==============================] - 0s 20ms/step - loss: 54.1758 - mse: 54.1758 - mape: 24956900.0000 - val_loss: 478.2351 - val_mse: 478.2351 - val_mape: 52.9902
# Epoch 46/100
# 4/4 [==============================] - 0s 14ms/step - loss: 53.5296 - mse: 53.5296 - mape: 24488232.0000 - val_loss: 478.8219 - val_mse: 478.8219 - val_mape: 53.0381
# Epoch 47/100
# 4/4 [==============================] - 0s 16ms/step - loss: 53.0283 - mse: 53.0283 - mape: 25087884.0000 - val_loss: 477.6438 - val_mse: 477.6438 - val_mape: 53.0345
# Epoch 48/100
# 4/4 [==============================] - 0s 19ms/step - loss: 52.4381 - mse: 52.4381 - mape: 25139736.0000 - val_loss: 477.7938 - val_mse: 477.7938 - val_mape: 53.0607
# Epoch 49/100
# 4/4 [==============================] - 0s 14ms/step - loss: 52.0488 - mse: 52.0488 - mape: 24153982.0000 - val_loss: 479.7957 - val_mse: 479.7957 - val_mape: 53.1980
# Epoch 50/100
# 4/4 [==============================] - 0s 16ms/step - loss: 51.5585 - mse: 51.5585 - mape: 24373158.0000 - val_loss: 482.6285 - val_mse: 482.6285 - val_mape: 53.2917
# Epoch 51/100
# 4/4 [==============================] - 0s 20ms/step - loss: 51.0437 - mse: 51.0437 - mape: 23776746.0000 - val_loss: 483.6801 - val_mse: 483.6801 - val_mape: 53.1645
# Epoch 52/100
# 4/4 [==============================] - 0s 21ms/step - loss: 50.4775 - mse: 50.4775 - mape: 24613480.0000 - val_loss: 483.9465 - val_mse: 483.9465 - val_mape: 53.0878
# Epoch 53/100
# 4/4 [==============================] - 0s 21ms/step - loss: 49.9632 - mse: 49.9632 - mape: 24900248.0000 - val_loss: 483.0718 - val_mse: 483.0718 - val_mape: 53.0512
# Epoch 54/100
# 4/4 [==============================] - 0s 16ms/step - loss: 49.4543 - mse: 49.4543 - mape: 25537438.0000 - val_loss: 482.1936 - val_mse: 482.1936 - val_mape: 53.0802
# Epoch 55/100
# 4/4 [==============================] - 0s 20ms/step - loss: 49.1911 - mse: 49.1911 - mape: 25549154.0000 - val_loss: 479.0511 - val_mse: 479.0511 - val_mape: 52.8982
# Epoch 56/100
# 4/4 [==============================] - 0s 14ms/step - loss: 48.5230 - mse: 48.5230 - mape: 27224554.0000 - val_loss: 478.5737 - val_mse: 478.5737 - val_mape: 53.0168
# Epoch 57/100
# 4/4 [==============================] - 0s 20ms/step - loss: 48.0728 - mse: 48.0728 - mape: 27754974.0000 - val_loss: 477.9779 - val_mse: 477.9779 - val_mape: 53.0485
# Epoch 58/100
# 4/4 [==============================] - 0s 19ms/step - loss: 47.7018 - mse: 47.7018 - mape: 28562110.0000 - val_loss: 478.9812 - val_mse: 478.9812 - val_mape: 53.2001
# Epoch 59/100
# 4/4 [==============================] - 0s 19ms/step - loss: 47.3119 - mse: 47.3119 - mape: 28960724.0000 - val_loss: 480.1165 - val_mse: 480.1165 - val_mape: 53.3854
# Epoch 60/100
# 4/4 [==============================] - 0s 14ms/step - loss: 46.8442 - mse: 46.8442 - mape: 29892582.0000 - val_loss: 481.4672 - val_mse: 481.4672 - val_mape: 53.4382
# Epoch 61/100
# 4/4 [==============================] - 0s 19ms/step - loss: 46.4656 - mse: 46.4656 - mape: 30446624.0000 - val_loss: 482.6611 - val_mse: 482.6611 - val_mape: 53.4460
# Epoch 62/100
# 4/4 [==============================] - 0s 13ms/step - loss: 46.0163 - mse: 46.0163 - mape: 30814292.0000 - val_loss: 484.1360 - val_mse: 484.1360 - val_mape: 53.5053
# Epoch 63/100
# 4/4 [==============================] - 0s 22ms/step - loss: 45.7045 - mse: 45.7045 - mape: 31164272.0000 - val_loss: 485.7621 - val_mse: 485.7621 - val_mape: 53.6382
# Epoch 64/100
# 4/4 [==============================] - 0s 19ms/step - loss: 45.1965 - mse: 45.1965 - mape: 32476662.0000 - val_loss: 488.5407 - val_mse: 488.5407 - val_mape: 53.7532
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 44.9027 - mse: 44.9027 - mape: 33633996.0000 - val_loss: 489.2865 - val_mse: 489.2865 - val_mape: 53.9175
# Epoch 66/100
# 4/4 [==============================] - 0s 19ms/step - loss: 44.4213 - mse: 44.4213 - mape: 33415346.0000 - val_loss: 489.9735 - val_mse: 489.9735 - val_mape: 53.8497
# Epoch 67/100
# 4/4 [==============================] - 0s 14ms/step - loss: 44.0025 - mse: 44.0025 - mape: 33760232.0000 - val_loss: 487.7979 - val_mse: 487.7979 - val_mape: 53.7785
# Epoch 68/100
# 4/4 [==============================] - 0s 15ms/step - loss: 43.6991 - mse: 43.6991 - mape: 33710792.0000 - val_loss: 488.0074 - val_mse: 488.0074 - val_mape: 53.8877
# Epoch 69/100
# 4/4 [==============================] - 0s 14ms/step - loss: 43.3773 - mse: 43.3773 - mape: 33866392.0000 - val_loss: 487.4779 - val_mse: 487.4779 - val_mape: 53.9463
# Epoch 70/100
# 4/4 [==============================] - 0s 24ms/step - loss: 43.1192 - mse: 43.1192 - mape: 34350324.0000 - val_loss: 486.8650 - val_mse: 486.8650 - val_mape: 53.8728
# Epoch 71/100
# 4/4 [==============================] - 0s 20ms/step - loss: 42.7871 - mse: 42.7871 - mape: 34969124.0000 - val_loss: 486.9397 - val_mse: 486.9397 - val_mape: 53.7351
# Epoch 72/100
# 4/4 [==============================] - 0s 20ms/step - loss: 42.2572 - mse: 42.2572 - mape: 34488436.0000 - val_loss: 488.4464 - val_mse: 488.4464 - val_mape: 53.7345
# Epoch 73/100
# 4/4 [==============================] - 0s 20ms/step - loss: 41.9792 - mse: 41.9792 - mape: 35620540.0000 - val_loss: 488.5249 - val_mse: 488.5249 - val_mape: 53.8883
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 41.4315 - mse: 41.4315 - mape: 37543120.0000 - val_loss: 487.5859 - val_mse: 487.5859 - val_mape: 53.9408
# Epoch 75/100
# 4/4 [==============================] - 0s 15ms/step - loss: 41.2078 - mse: 41.2078 - mape: 38429220.0000 - val_loss: 485.8667 - val_mse: 485.8667 - val_mape: 53.7164
# Epoch 76/100
# 4/4 [==============================] - 0s 14ms/step - loss: 40.6550 - mse: 40.6550 - mape: 38419208.0000 - val_loss: 486.6435 - val_mse: 486.6435 - val_mape: 53.9735
# Epoch 77/100
# 4/4 [==============================] - 0s 16ms/step - loss: 40.2724 - mse: 40.2724 - mape: 39275632.0000 - val_loss: 487.9252 - val_mse: 487.9252 - val_mape: 54.0564
# Epoch 78/100
# 4/4 [==============================] - 0s 14ms/step - loss: 39.9525 - mse: 39.9525 - mape: 39155036.0000 - val_loss: 488.2662 - val_mse: 488.2662 - val_mape: 53.8542
# Epoch 79/100
# 4/4 [==============================] - 0s 20ms/step - loss: 39.5256 - mse: 39.5256 - mape: 39291552.0000 - val_loss: 489.0754 - val_mse: 489.0754 - val_mape: 53.8084
# Epoch 80/100
# 4/4 [==============================] - 0s 14ms/step - loss: 39.2101 - mse: 39.2101 - mape: 39800980.0000 - val_loss: 489.4803 - val_mse: 489.4803 - val_mape: 53.9317
# Epoch 81/100
# 4/4 [==============================] - 0s 15ms/step - loss: 38.8540 - mse: 38.8540 - mape: 40077400.0000 - val_loss: 491.3317 - val_mse: 491.3317 - val_mape: 54.1404
# Epoch 82/100
# 4/4 [==============================] - 0s 21ms/step - loss: 38.4803 - mse: 38.4803 - mape: 39956728.0000 - val_loss: 492.8315 - val_mse: 492.8315 - val_mape: 54.2471
# Epoch 83/100
# 4/4 [==============================] - 0s 17ms/step - loss: 38.2455 - mse: 38.2455 - mape: 39558156.0000 - val_loss: 494.3755 - val_mse: 494.3755 - val_mape: 54.3779
# Epoch 84/100
# 4/4 [==============================] - 0s 20ms/step - loss: 38.0419 - mse: 38.0419 - mape: 40473020.0000 - val_loss: 493.3460 - val_mse: 493.3460 - val_mape: 54.3146
# Epoch 85/100
# 4/4 [==============================] - 0s 20ms/step - loss: 37.7349 - mse: 37.7349 - mape: 41038884.0000 - val_loss: 494.8264 - val_mse: 494.8264 - val_mape: 54.5159
# Epoch 86/100
# 4/4 [==============================] - 0s 16ms/step - loss: 37.5675 - mse: 37.5675 - mape: 41368360.0000 - val_loss: 495.0231 - val_mse: 495.0231 - val_mape: 54.4733
# Epoch 87/100
# 4/4 [==============================] - 0s 20ms/step - loss: 37.1919 - mse: 37.1919 - mape: 41641768.0000 - val_loss: 497.9846 - val_mse: 497.9846 - val_mape: 54.5771
# Epoch 88/100
# 4/4 [==============================] - 0s 21ms/step - loss: 36.9198 - mse: 36.9198 - mape: 42460540.0000 - val_loss: 498.8720 - val_mse: 498.8720 - val_mape: 54.6952
# Epoch 89/100
# 4/4 [==============================] - 0s 20ms/step - loss: 36.6435 - mse: 36.6435 - mape: 41917940.0000 - val_loss: 498.2849 - val_mse: 498.2849 - val_mape: 54.8079
# Epoch 90/100
# 4/4 [==============================] - 0s 16ms/step - loss: 36.4136 - mse: 36.4136 - mape: 42392800.0000 - val_loss: 498.3320 - val_mse: 498.3320 - val_mape: 54.8504
# Epoch 91/100
# 4/4 [==============================] - 0s 16ms/step - loss: 36.2042 - mse: 36.2042 - mape: 43066648.0000 - val_loss: 498.8427 - val_mse: 498.8427 - val_mape: 54.8733
# Epoch 92/100
# 4/4 [==============================] - 0s 16ms/step - loss: 35.9356 - mse: 35.9356 - mape: 43213072.0000 - val_loss: 500.9489 - val_mse: 500.9489 - val_mape: 54.9698
# Epoch 93/100
# 4/4 [==============================] - 0s 21ms/step - loss: 35.8171 - mse: 35.8171 - mape: 43001572.0000 - val_loss: 500.1169 - val_mse: 500.1169 - val_mape: 54.6677
# Epoch 94/100
# 4/4 [==============================] - 0s 16ms/step - loss: 35.4943 - mse: 35.4943 - mape: 43272368.0000 - val_loss: 496.7219 - val_mse: 496.7219 - val_mape: 54.5163
# Epoch 95/100
# 4/4 [==============================] - 0s 21ms/step - loss: 35.3044 - mse: 35.3044 - mape: 42952284.0000 - val_loss: 494.3966 - val_mse: 494.3966 - val_mape: 54.6252
# Epoch 96/100
# 4/4 [==============================] - 0s 22ms/step - loss: 35.0603 - mse: 35.0603 - mape: 42818308.0000 - val_loss: 495.7893 - val_mse: 495.7893 - val_mape: 54.8167
# Epoch 97/100
# 4/4 [==============================] - 0s 20ms/step - loss: 34.8884 - mse: 34.8884 - mape: 42466992.0000 - val_loss: 495.0160 - val_mse: 495.0160 - val_mape: 54.7082
# Epoch 98/100
# 4/4 [==============================] - 0s 19ms/step - loss: 34.6698 - mse: 34.6698 - mape: 42951612.0000 - val_loss: 496.4719 - val_mse: 496.4719 - val_mape: 54.9747
# Epoch 99/100
# 4/4 [==============================] - 0s 20ms/step - loss: 34.3755 - mse: 34.3755 - mape: 43466388.0000 - val_loss: 495.3387 - val_mse: 495.3387 - val_mape: 54.8814
# Epoch 100/100
# 4/4 [==============================] - 0s 18ms/step - loss: 34.2136 - mse: 34.2136 - mape: 43411352.0000 - val_loss: 495.9425 - val_mse: 495.9425 - val_mape: 55.0370

# %% [markdown]
# This **whole** big log looks pretty! I like it.

# %% [markdown]
# #### ➡ See the loss for validation and training...
# *Believe me, this plot is great, you will feel you are monitoring something...*

# %%
plt.plot(result.history['loss'], label="Train loss")
plt.plot(result.history['val_loss'], label="Validation loss")
plt.xlabel("← Epoch →", labelpad=20)
plt.ylabel("← MSE →", labelpad=20)
plt.title("Model performance during training")
plt.legend();

# %% [markdown]
# Seems to be pretty good.

# %% [markdown]
# #### ➡ Predict and plot the results

# %%
pred_tr = model.predict(Xtr).flatten()
pred_te = model.predict(Xte).flatten()
# Out:
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
passengers.loc[train_idx[lag+1:], "OneStep Diff Train Prediction"] = pred_tr
passengers.loc[test_idx, "OneStep Diff Test Prediction"] = pred_te

# %%
passengers[["diffPassengers",
            "OneStep Diff Train Prediction",
            "OneStep Diff Test Prediction"]].plot()
plt.title("One step model differenced prediction (for train & test)");

# %%
def evaluate_results(true, pred):
    print("R2: ", r2_score(true, pred))
    print("MAPE:", mean_absolute_percentage_error(true, pred), "%")

# %%
evaluate_results(ytr, pred_tr)
# Out:
# R2:  0.9680583382588505
# MAPE: 193043474622688.1 %

# %% [markdown]
# Oops, the MAPE is like 🤯 <br>
# I think we should **undo** the difference, and then try assessing the result.

# %% [markdown]
# #### Reall how to undo...

# %% [markdown]
# For one-step: *just add the previous **true** step to the prediction.*

# %%
prev = passengers["Passengers"].shift(1)

# %%
passengers.loc[train_idx[lag+1:], "OneStep Orig Train Pred"] = prev[train_idx[lag+1:]] + pred_tr
passengers.loc[test_idx, "OneStep Orig Test Pred"] = prev[test_idx] + pred_te

# %%
passengers[["Passengers", "OneStep Orig Train Pred", "OneStep Orig Test Pred"]].plot()
plt.title("One step model prediction (for train & test)");

# %%
evaluate_results(passengers.loc[test_idx, "Passengers"], passengers.loc[test_idx, "OneStep Orig Test Pred"])
# Out:
# R2:  0.9104711769318388
# MAPE: 0.03536114345161248 %

# %% [markdown]
# The results are pretty good guys!
#
# I know we have achieved this **after all of the work**. Looks a lot of code... but it isn't. These things are looking long because of the **code re-producubility**. If I were to do this kind of stuff, it would take very less time and code.
# ___
# Let's have a look on other type of methods.

# %% [markdown]
# #

# %% [markdown]
# ## `2.` Multi step model

# %% [markdown]
# Since the model is **already trained** we don't need to train it once again. We will just **change the way we forecast**.

# %% [markdown]
# #### ➡ Predict and plot the results

# %%
last_xte = Xte[0].reshape(1, -1)
multi_step_pred = []
for i in range(yte.shape[0]):
    pred = model.predict(last_xte)[0]
    last_xte = np.roll(last_xte, -1)
    last_xte[-1][-1] = pred

    multi_step_pred.append(pred)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# <ipython-input-37-a38836be9697>:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_xte[-1][-1] = pred
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
passengers.loc[test_idx, "MultiStep Test Prediction"] = multi_step_pred

# %%
passengers[["diffPassengers", "MultiStep Test Prediction"]].plot()
plt.title("Multi step model differenced prediction test");

# %% [markdown]
# #### Reall how to undo...

# %% [markdown]
# For multi-step: *just add the previous **true** step and perform cumsum.*

# %%
last_train = passengers.loc[train_idx[-1], "Passengers"]

# %%
passengers.loc[test_idx, "MultiStep Orig Test Pred"] = last_train + np.cumsum(multi_step_pred)

# %%
passengers[["Passengers", "OneStep Orig Test Pred", "MultiStep Orig Test Pred"]].plot()
plt.title("Multistep model prediction for test");

# %%
evaluate_results(passengers.loc[test_idx, "Passengers"], passengers.loc[test_idx, "MultiStep Orig Test Pred"])
# Out:
# R2:  0.9458080631147789
# MAPE: 0.03007273423718085 %

# %% [markdown]
# This is amazing as well!

# %% [markdown]
# #

# %% [markdown]
# ## `3.` Multi output model

# %% [markdown]
# Here, we will need to create different training and testing data... and will need to re-train the model from scratch. Not only that, the model's **structure** will change as well.

# %%
# for this we will have to construct another dataset
# the current supervised dataset won't help.

lag = 12
h = 12
X, y = [], []
for offset in range(len(np_data) - lag - h + 1):
    X.append(np_data[offset : offset+lag])
    y.append(np_data[offset+lag : offset+lag+h])

X = np.array(X)
y = np.array(y)

# %%
Xtr_m, ytr_m = X[:-1], y[:-1]
Xte_m, yte_m = X[[-1]], y[[-1]]

# %%
Xtr_m.shape
# Out:
# (119, 12)

# %%
ytr_m.shape
# Out:
# (119, 12)

# %% [markdown]
# ####  Model creation

# %%
input_layer = Input(shape=(Xtr_m.shape[1], ))
h1 = Dense(32, activation="relu")(input_layer)
h1 = Dense(32, activation="relu")(h1)
output_layer = Dense(ytr_m.shape[1])(h1)
model = Model(input_layer, output_layer)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 12)]              0
#
#  dense_7 (Dense)             (None, 32)                416
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dense_9 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 1868 (7.30 KB)
# Trainable params: 1868 (7.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile
model.compile(optimizer="adam", loss="mse")

# %%
# fit
mtr_result = model.fit(Xtr_m, ytr_m,
                       epochs=100,
                       validation_data=(Xte_m, yte_m))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 71ms/step - loss: 1582.7172 - val_loss: 2533.6633
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1456.4224 - val_loss: 2367.8943
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1344.8892 - val_loss: 2241.1169
# Epoch 4/100
# 4/4 [==============================] - 0s 17ms/step - loss: 1254.2812 - val_loss: 2116.3428
# Epoch 5/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1176.5483 - val_loss: 2008.9868
# Epoch 6/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1101.8931 - val_loss: 1918.3379
# Epoch 7/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1046.8217 - val_loss: 1849.6973
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 992.6601 - val_loss: 1792.3741
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 949.3632 - val_loss: 1743.5479
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 903.9056 - val_loss: 1694.7233
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 864.6363 - val_loss: 1648.1992
# Epoch 12/100
# 4/4 [==============================] - 0s 14ms/step - loss: 831.3146 - val_loss: 1604.9232
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 795.0622 - val_loss: 1562.8302
# Epoch 14/100
# 4/4 [==============================] - 0s 17ms/step - loss: 761.5697 - val_loss: 1516.3470
# Epoch 15/100
# 4/4 [==============================] - 0s 23ms/step - loss: 728.2682 - val_loss: 1466.6562
# Epoch 16/100
# 4/4 [==============================] - 0s 12ms/step - loss: 700.8052 - val_loss: 1427.6093
# Epoch 17/100
# 4/4 [==============================] - 0s 13ms/step - loss: 671.2117 - val_loss: 1386.3636
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: 642.3187 - val_loss: 1342.7213
# Epoch 19/100
# 4/4 [==============================] - 0s 12ms/step - loss: 616.1378 - val_loss: 1303.3580
# Epoch 20/100
# 4/4 [==============================] - 0s 15ms/step - loss: 590.2095 - val_loss: 1258.1334
# Epoch 21/100
# 4/4 [==============================] - 0s 13ms/step - loss: 565.7864 - val_loss: 1216.7103
# Epoch 22/100
# 4/4 [==============================] - 0s 19ms/step - loss: 541.9071 - val_loss: 1173.9198
# Epoch 23/100
# 4/4 [==============================] - 0s 13ms/step - loss: 518.7556 - val_loss: 1129.5685
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 496.5056 - val_loss: 1091.6808
# Epoch 25/100
# 4/4 [==============================] - 0s 15ms/step - loss: 475.6891 - val_loss: 1051.1105
# Epoch 26/100
# 4/4 [==============================] - 0s 14ms/step - loss: 453.9901 - val_loss: 1015.6901
# Epoch 27/100
# 4/4 [==============================] - 0s 12ms/step - loss: 434.9392 - val_loss: 976.4099
# Epoch 28/100
# 4/4 [==============================] - 0s 27ms/step - loss: 415.6430 - val_loss: 937.6440
# Epoch 29/100
# 4/4 [==============================] - 0s 28ms/step - loss: 398.0482 - val_loss: 901.7375
# Epoch 30/100
# 4/4 [==============================] - 0s 26ms/step - loss: 380.6228 - val_loss: 864.3223
# Epoch 31/100
# 4/4 [==============================] - 0s 18ms/step - loss: 364.2553 - val_loss: 824.6624
# Epoch 32/100
# 4/4 [==============================] - 0s 25ms/step - loss: 348.8401 - val_loss: 785.1473
# Epoch 33/100
# 4/4 [==============================] - 0s 24ms/step - loss: 333.5748 - val_loss: 756.1616
# Epoch 34/100
# 4/4 [==============================] - 0s 24ms/step - loss: 318.8990 - val_loss: 728.0184
# Epoch 35/100
# 4/4 [==============================] - 0s 21ms/step - loss: 305.9195 - val_loss: 699.3094
# Epoch 36/100
# 4/4 [==============================] - 0s 17ms/step - loss: 292.7870 - val_loss: 675.7629
# Epoch 37/100
# 4/4 [==============================] - 0s 23ms/step - loss: 280.4164 - val_loss: 639.9861
# Epoch 38/100
# 4/4 [==============================] - 0s 18ms/step - loss: 269.3353 - val_loss: 616.4808
# Epoch 39/100
# 4/4 [==============================] - 0s 22ms/step - loss: 258.4789 - val_loss: 594.5823
# Epoch 40/100
# 4/4 [==============================] - 0s 26ms/step - loss: 247.8307 - val_loss: 581.8323
# Epoch 41/100
# 4/4 [==============================] - 0s 25ms/step - loss: 237.1730 - val_loss: 560.9365
# Epoch 42/100
# 4/4 [==============================] - 0s 27ms/step - loss: 227.9581 - val_loss: 546.5092
# Epoch 43/100
# 4/4 [==============================] - 0s 17ms/step - loss: 219.4050 - val_loss: 530.8766
# Epoch 44/100
# 4/4 [==============================] - 0s 22ms/step - loss: 210.5295 - val_loss: 517.9200
# Epoch 45/100
# 4/4 [==============================] - 0s 23ms/step - loss: 202.6196 - val_loss: 511.5725
# Epoch 46/100
# 4/4 [==============================] - 0s 28ms/step - loss: 195.0206 - val_loss: 500.9946
# Epoch 47/100
# 4/4 [==============================] - 0s 29ms/step - loss: 187.8950 - val_loss: 492.8331
# Epoch 48/100
# 4/4 [==============================] - 0s 27ms/step - loss: 181.1317 - val_loss: 477.9469
# Epoch 49/100
# 4/4 [==============================] - 0s 26ms/step - loss: 174.6308 - val_loss: 462.0216
# Epoch 50/100
# 4/4 [==============================] - 0s 26ms/step - loss: 168.7184 - val_loss: 448.8395
# Epoch 51/100
# 4/4 [==============================] - 0s 26ms/step - loss: 163.1488 - val_loss: 435.7512
# Epoch 52/100
# 4/4 [==============================] - 0s 21ms/step - loss: 157.8384 - val_loss: 425.1681
# Epoch 53/100
# 4/4 [==============================] - 0s 26ms/step - loss: 152.8190 - val_loss: 415.8527
# Epoch 54/100
# 4/4 [==============================] - 0s 20ms/step - loss: 148.4413 - val_loss: 405.1180
# Epoch 55/100
# 4/4 [==============================] - 0s 27ms/step - loss: 144.2140 - val_loss: 396.6902
# Epoch 56/100
# 4/4 [==============================] - 0s 29ms/step - loss: 140.2756 - val_loss: 389.6782
# Epoch 57/100
# 4/4 [==============================] - 0s 32ms/step - loss: 136.5134 - val_loss: 386.3103
# Epoch 58/100
# 4/4 [==============================] - 0s 19ms/step - loss: 133.3103 - val_loss: 383.9593
# Epoch 59/100
# 4/4 [==============================] - 0s 26ms/step - loss: 130.1045 - val_loss: 381.6100
# Epoch 60/100
# 4/4 [==============================] - 0s 17ms/step - loss: 127.1714 - val_loss: 374.1066
# Epoch 61/100
# 4/4 [==============================] - 0s 14ms/step - loss: 124.5017 - val_loss: 371.0575
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 121.8650 - val_loss: 373.7620
# Epoch 63/100
# 4/4 [==============================] - 0s 15ms/step - loss: 119.7134 - val_loss: 372.6090
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 117.2877 - val_loss: 370.6025
# Epoch 65/100
# 4/4 [==============================] - 0s 12ms/step - loss: 115.1711 - val_loss: 371.1478
# Epoch 66/100
# 4/4 [==============================] - 0s 12ms/step - loss: 113.2760 - val_loss: 370.6132
# Epoch 67/100
# 4/4 [==============================] - 0s 14ms/step - loss: 111.5011 - val_loss: 363.6339
# Epoch 68/100
# 4/4 [==============================] - 0s 14ms/step - loss: 110.0626 - val_loss: 358.6597
# Epoch 69/100
# 4/4 [==============================] - 0s 13ms/step - loss: 108.3570 - val_loss: 356.5165
# Epoch 70/100
# 4/4 [==============================] - 0s 14ms/step - loss: 106.8469 - val_loss: 355.3680
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 105.3866 - val_loss: 353.1804
# Epoch 72/100
# 4/4 [==============================] - 0s 19ms/step - loss: 104.1108 - val_loss: 355.0565
# Epoch 73/100
# 4/4 [==============================] - 0s 14ms/step - loss: 102.9422 - val_loss: 358.5669
# Epoch 74/100
# 4/4 [==============================] - 0s 21ms/step - loss: 101.7157 - val_loss: 354.8855
# Epoch 75/100
# 4/4 [==============================] - 0s 13ms/step - loss: 100.8130 - val_loss: 355.1247
# Epoch 76/100
# 4/4 [==============================] - 0s 14ms/step - loss: 99.7618 - val_loss: 357.8884
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 98.9589 - val_loss: 357.2846
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 98.0092 - val_loss: 359.3831
# Epoch 79/100
# 4/4 [==============================] - 0s 14ms/step - loss: 97.2230 - val_loss: 359.6018
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 96.4181 - val_loss: 360.5177
# Epoch 81/100
# 4/4 [==============================] - 0s 13ms/step - loss: 95.7549 - val_loss: 361.0062
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 95.0179 - val_loss: 363.8135
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 94.3481 - val_loss: 364.6587
# Epoch 84/100
# 4/4 [==============================] - 0s 14ms/step - loss: 93.7756 - val_loss: 364.2488
# Epoch 85/100
# 4/4 [==============================] - 0s 14ms/step - loss: 93.1462 - val_loss: 360.7863
# Epoch 86/100
# 4/4 [==============================] - 0s 14ms/step - loss: 92.5650 - val_loss: 360.1227
# Epoch 87/100
# 4/4 [==============================] - 0s 15ms/step - loss: 92.0381 - val_loss: 364.7648
# Epoch 88/100
# 4/4 [==============================] - 0s 13ms/step - loss: 91.5122 - val_loss: 366.6521
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 90.9397 - val_loss: 362.6302
# Epoch 90/100
# 4/4 [==============================] - 0s 15ms/step - loss: 90.4829 - val_loss: 364.8641
# Epoch 91/100
# 4/4 [==============================] - 0s 19ms/step - loss: 89.9764 - val_loss: 367.3894
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 89.5511 - val_loss: 367.2307
# Epoch 93/100
# 4/4 [==============================] - 0s 20ms/step - loss: 89.1003 - val_loss: 374.9366
# Epoch 94/100
# 4/4 [==============================] - 0s 13ms/step - loss: 88.6735 - val_loss: 376.0041
# Epoch 95/100
# 4/4 [==============================] - 0s 15ms/step - loss: 88.2765 - val_loss: 375.1853
# Epoch 96/100
# 4/4 [==============================] - 0s 14ms/step - loss: 87.8199 - val_loss: 372.9635
# Epoch 97/100
# 4/4 [==============================] - 0s 13ms/step - loss: 87.5014 - val_loss: 375.5760
# Epoch 98/100
# 4/4 [==============================] - 0s 14ms/step - loss: 87.1630 - val_loss: 376.3647
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 86.6303 - val_loss: 374.6688
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 86.3212 - val_loss: 374.5301

# %%
plt.plot(mtr_result.history['loss'], label="Train loss")
plt.plot(mtr_result.history['val_loss'], label="Validation loss")
plt.xlabel("← Epoch →", labelpad=20)
plt.ylabel("← MSE →", labelpad=20)
plt.title("Model performance during training")
plt.legend();

# %%
mtr_test_pred = model.predict(Xte_m)
# Out:
# 1/1 [==============================] - 0s 60ms/step

# %%
passengers.loc[test_idx, "MultiOutput Orig Test Pred"] = last_train + np.cumsum(mtr_test_pred)

# %%
passengers[["Passengers", "OneStep Orig Test Pred", "MultiStep Orig Test Pred", "MultiOutput Orig Test Pred"]].plot()
plt.title("Multistep model prediction for test");

# %%
evaluate_results(passengers.loc[test_idx, "Passengers"], passengers.loc[test_idx, "MultiOutput Orig Test Pred"])
# Out:
# R2:  0.9428678922778925
# MAPE: 0.031936073116740384 %

# %% [markdown]
# The best of all. Great. Great.

# %% [markdown]
# #

# %% [markdown]
# # Without Differencing

# %%
passengers.columns
# Out:
# Index(['Passengers', 'diffPassengers', 'OneStep Diff Train Prediction',
#        'OneStep Diff Test Prediction', 'OneStep Orig Train Pred',
#        'OneStep Orig Test Pred', 'MultiStep Test Prediction',
#        'MultiStep Orig Test Pred', 'MultiOutput Orig Test Pred'],
#       dtype='object')

# %%
# reset
passengers = passengers.drop(['diffPassengers', 'OneStep Diff Train Prediction',
       'OneStep Diff Test Prediction', 'OneStep Orig Train Pred',
       'OneStep Orig Test Pred', 'MultiStep Test Prediction',
       'MultiStep Orig Test Pred', 'MultiOutput Orig Test Pred'], axis=1)

# %% [markdown]
# # `1.` One step model

# %%
lag = 12
train_idx = passengers.iloc[:-lag].index
test_idx = passengers.iloc[-lag:].index

# %%
np_data = passengers.loc[:, "Passengers"].dropna().values
X = []
Y = []

for i in range(0, np_data.shape[0] - lag):
    x = np_data[i : i + lag]
    y = np_data[i + lag]
    X.append(x)
    Y.append(y)

X = np.array(X)
Y = np.array(Y)

# %%
Xtr, Xte = X[:-lag], X[-lag:]
ytr, yte = Y[:-lag], Y[-lag:]

# %%
# everything in a single cell
input_layer = Input(shape=(Xtr.shape[1],))
h1 = Dense(32, activation="relu")(input_layer)
h2 = Dense(16, activation="relu")(h1)
output_layer = Dense(1, activation=None)(h2)
model = Model(input_layer, output_layer)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mse", "mape"])

# %%
result = model.fit(Xtr, ytr,
         epochs=1000,
         validation_data=(Xte, yte), verbose=0)

# %% [markdown]
# Yeah, keeping verbose `0` 🙂

# %%
plt.plot(result.history['loss'], label="Train loss")
plt.plot(result.history['val_loss'], label="Validation loss")
plt.xlabel("← Epoch →", labelpad=20)
plt.ylabel("← MSE →", labelpad=20)
plt.title("Model performance during training")
plt.legend();

# %% [markdown]
# Have a look! **without differencing** more than 200 epochs are needed!

# %%
pred_tr = model.predict(Xtr).flatten()
pred_te = model.predict(Xte).flatten()
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
pred_tr.shape
# Out:
# (120,)

# %%
passengers.loc[train_idx[lag:], "OneStep Train Prediction"] = pred_tr
passengers.loc[test_idx, "OneStep Test Prediction"] = pred_te

# %%
passengers[["Passengers",
            "OneStep Train Prediction",
            "OneStep Test Prediction"]].plot()
plt.title("One step model prediction (for train & test)");

# %%
evaluate_results(yte, pred_te)
# Out:
# R2:  0.9498977761991291
# MAPE: 0.030884826369757257 %

# %% [markdown]
# Doing already good here.

# %% [markdown]
# #

# %% [markdown]
# ## `2.` Multi step model

# %% [markdown]
# Since the model is **already trained** we don't need to train it once again. We will just **change the way we forecast**.

# %% [markdown]
# #### ➡ Predict and plot the results

# %%
last_xte = Xte[0].reshape(1, -1)
multi_step_pred = []
for i in range(yte.shape[0]):
    pred = model.predict(last_xte)[0]
    last_xte = np.roll(last_xte, -1)
    last_xte[-1][-1] = pred

    multi_step_pred.append(pred)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# <ipython-input-71-a38836be9697>:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_xte[-1][-1] = pred
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
passengers.loc[test_idx, "MultiStep Test Prediction"] = multi_step_pred

# %%
passengers[["Passengers", "MultiStep Test Prediction"]].plot()
plt.title("Multi step model prediction test");

# %%
evaluate_results(passengers.loc[test_idx, "Passengers"], passengers.loc[test_idx, "MultiStep Test Prediction"])
# Out:
# R2:  0.951707881105418
# MAPE: 0.030705299138174044 %

# %% [markdown]
# #

# %% [markdown]
# ## `3.` Multi output model

# %% [markdown]
# Here, we will need to create different training and testing data... and will need to re-train the model from scratch. Not only that, the model's **structure** will change as well.

# %%
# for this we will have to construct another dataset
# the current supervised dataset won't help.

lag = 12
h = 12
X, y = [], []
for offset in range(len(np_data) - lag - h + 1):
    X.append(np_data[offset : offset+lag])
    y.append(np_data[offset+lag : offset+lag+h])

X = np.array(X)
y = np.array(y)

# %%
Xtr_m, ytr_m = X[:-1], y[:-1]
Xte_m, yte_m = X[[-1]], y[[-1]]

# %%
Xtr_m.shape
# Out:
# (120, 12)

# %%
ytr_m.shape
# Out:
# (120, 12)

# %% [markdown]
# ####  Model creation

# %%
input_layer = Input(shape=(Xtr_m.shape[1], ))
h1 = Dense(32, activation="relu")(input_layer)
h1 = Dense(32, activation="relu")(h1)
output_layer = Dense(ytr_m.shape[1])(h1)
model = Model(input_layer, output_layer)

# %%
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 12)]              0
#
#  dense_13 (Dense)            (None, 32)                416
#
#  dense_14 (Dense)            (None, 32)                1056
#
#  dense_15 (Dense)            (None, 12)                396
#
# =================================================================
# Total params: 1868 (7.30 KB)
# Trainable params: 1868 (7.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile
model.compile(optimizer="adam", loss="mse")

# %%
# fit
mtr_result = model.fit(Xtr_m, ytr_m,
                       epochs=1000,
                       validation_data=(Xte_m, yte_m),
                       verbose=0)

# %%
plt.plot(mtr_result.history['loss'], label="Train loss")
plt.plot(mtr_result.history['val_loss'], label="Validation loss")
plt.xlabel("← Epoch →", labelpad=20)
plt.ylabel("← MSE →", labelpad=20)
plt.title("Model performance during training")
plt.legend();

# %%
mtr_test_pred = model.predict(Xte_m)
# Out:
# 1/1 [==============================] - 0s 91ms/step

# %%
mtr_test_pred = mtr_test_pred.flatten()

# %%
passengers.loc[test_idx, "MultiOutput Test Pred"] = mtr_test_pred

# %%
passengers[["Passengers",
            "OneStep Test Prediction",
            "MultiStep Test Prediction",
            "MultiOutput Test Pred"]].plot()
plt.title("Multistep model prediction for test");

# %%
evaluate_results(passengers.loc[test_idx, "Passengers"], passengers.loc[test_idx, "MultiOutput Test Pred"])
# Out:
# R2:  0.9407073889042789
# MAPE: 0.034417121202802915 %

# %% [markdown]
# Again, the best of all.

# %% [markdown]
# #

# %% [markdown]
# # Great, indeed!
# We have worked pretty great achieving a good R2. See, we have not considered going with walk-forward validation and grid-search to adjust my hyperparams, but it can be done.
#
# See you in the next book.
